# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch import nn, optim

import torch.nn as nn
import  torch.nn.functional as F

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.device(device)
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
def get_transforms():
    transform = transforms.Compose(
        [transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),]
    )

    return transform

def get_dataset(download=True):
    transforms = get_transforms()
    trainset = datasets.MNIST('./training_dataset', download = download, train = True, transform = transforms)
    valset = datasets.MNIST('./validation_dataset', download = download, train = False, transform = transforms)

    train_loader = DataLoader(trainset, batch_size=64, shuffle=True)
    val_loader = DataLoader(valset, batch_size=64, shuffle=True)

    return train_loader, val_loader

def plot_data(images):
    figure = plt.figure()
    num_of_images = 60
    for index in range(1, num_of_images + 1):
        plt.subplot(6, 10, index)
        plt.axis('off')
        plt.imshow(images[index].numpy().squeeze(), cmap='gray_r')

# %%
def train(model, optimizer, train_loader, train_losses, train_counter, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        data = torch.as_tensor(data, device = device)
        target = torch.as_tensor(target, device = device)
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(epoch, batch_idx * len(data), len(train_loader.dataset), 
            100. * batch_idx / len(train_loader), 
            loss.item()))
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))

        torch.save(model.state_dict(), './results/notebook_digit_recognizer.pth')
        torch.save(optimizer.state_dict(), './optimizer/notebook_optimizer.pth')

        return train_losses, train_counter, True

def test(model, test_loader, test_losses, test_counter):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data = torch.tensor(data).to(device)
            target = torch.tensor(target).to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, size_average=False).item()
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))

    return test_losses, True

# %%
class MNIST_NET(nn.Module):
    def __init__(self):
        super(MNIST_NET, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.dropput = nn.Dropout2d(.30)
        self.fcn1 = nn.Linear(in_features = 320, out_features = 50)
        self.fcn2 = nn.Linear(in_features = 50, out_features = 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.dropput(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fcn1(x))
        x = F.dropout(x, training=self.training)
        x = self.fcn2(x)
        return F.log_softmax(x)

# %%
train_loader, val_loader = get_dataset(download = False)
dataiter = iter(train_loader)

images, labels = dataiter.next()

print(images.shape)
print(labels.shape)

plot_data(images)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
n_epochs = 300
learning_rate = 0.01
momentum = 0.9
batch_size_train = 64
batch_size_test = 1000
log_interval = 10

#importing model
model = MNIST_NET()
if device == 'cuda':
    model.cuda()
# optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum = momentum)
optimizer = optim.Adam(model.parameters(), lr = learning_rate)

train_losses = []
test_losses = []

train_counter = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

print(model)

# model_state = torch.load('digit_recognizer.pth', map_location=device)
# model.load_state_dict(model_state)

# optimizer_state = torch.load('optimizer.pth', map_location=device)
# optimizer.load_state_dict(optimizer_state)

test_losses, is_tested = test(model, val_loader, test_losses, test_counter)
for epoch in range(n_epochs+1):
    train_loss, train_counter, is_trained = train(model, optimizer, train_loader, train_losses, train_counter, epoch)
    test_losses, is_tested = test(model, val_loader, test_losses, test_counter)
# Out:
# MNIST_NET(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (dropput): Dropout2d(p=0.3, inplace=False)
#   (fcn1): Linear(in_features=320, out_features=50, bias=True)
#   (fcn2): Linear(in_features=50, out_features=10, bias=True)
# )
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 2.3144, Accuracy: 828/10000 (8%)
#
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.322568
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# /home/arfan/.conda/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Test set: Avg. loss: 2.3428, Accuracy: 1387/10000 (14%)
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.326835
#
# Test set: Avg. loss: 2.3173, Accuracy: 1650/10000 (16%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.344568
#
# Test set: Avg. loss: 2.2736, Accuracy: 1825/10000 (18%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.245529
#
# Test set: Avg. loss: 2.2700, Accuracy: 984/10000 (10%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.272321
#
# Test set: Avg. loss: 2.2589, Accuracy: 987/10000 (10%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.239011
#
# Test set: Avg. loss: 2.2349, Accuracy: 1285/10000 (13%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.280326
#
# Test set: Avg. loss: 2.2245, Accuracy: 1862/10000 (19%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.233996
#
# Test set: Avg. loss: 2.2014, Accuracy: 2883/10000 (29%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.185583
#
# Test set: Avg. loss: 2.1620, Accuracy: 3148/10000 (31%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 2.259115
#
# Test set: Avg. loss: 2.1081, Accuracy: 3329/10000 (33%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 2.089883
#
# Test set: Avg. loss: 2.0322, Accuracy: 3087/10000 (31%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 2.223707
#
# Test set: Avg. loss: 1.9625, Accuracy: 3759/10000 (38%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 1.994629
#
# Test set: Avg. loss: 1.8724, Accuracy: 4456/10000 (45%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 1.998967
#
# Test set: Avg. loss: 1.7602, Accuracy: 5037/10000 (50%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 1.724457
#
# Test set: Avg. loss: 1.6293, Accuracy: 5382/10000 (54%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 1.928586
#
# Test set: Avg. loss: 1.4976, Accuracy: 5816/10000 (58%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 2.023586
#
# Test set: Avg. loss: 1.4110, Accuracy: 6316/10000 (63%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 1.626673
#
# Test set: Avg. loss: 1.3434, Accuracy: 6107/10000 (61%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 1.710522
#
# Test set: Avg. loss: 1.3012, Accuracy: 5897/10000 (59%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 1.650403
#
# Test set: Avg. loss: 1.2364, Accuracy: 6305/10000 (63%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 1.877370
#
# Test set: Avg. loss: 1.2211, Accuracy: 6575/10000 (66%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 1.527428
#
# Test set: Avg. loss: 1.2188, Accuracy: 6654/10000 (67%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 1.545279
#
# Test set: Avg. loss: 1.2121, Accuracy: 6822/10000 (68%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 1.256654
#
# Test set: Avg. loss: 1.1497, Accuracy: 7152/10000 (72%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 1.422334
#
# Test set: Avg. loss: 1.0567, Accuracy: 7571/10000 (76%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 1.569697
#
# Test set: Avg. loss: 0.9744, Accuracy: 8037/10000 (80%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 1.697587
#
# Test set: Avg. loss: 0.9305, Accuracy: 7539/10000 (75%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 1.082048
#
# Test set: Avg. loss: 0.8814, Accuracy: 7393/10000 (74%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 1.234169
#
# Test set: Avg. loss: 0.8273, Accuracy: 7432/10000 (74%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 1.164526
#
# Test set: Avg. loss: 0.7807, Accuracy: 7478/10000 (75%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 1.205945
#
# Test set: Avg. loss: 0.7308, Accuracy: 7658/10000 (77%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 1.380583
#
# Test set: Avg. loss: 0.6886, Accuracy: 7951/10000 (80%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 1.319037
#
# Test set: Avg. loss: 0.6618, Accuracy: 8069/10000 (81%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 1.072576
#
# Test set: Avg. loss: 0.6481, Accuracy: 8066/10000 (81%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 1.136029
#
# Test set: Avg. loss: 0.6449, Accuracy: 7990/10000 (80%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 1.143713
#
# Test set: Avg. loss: 0.6517, Accuracy: 7917/10000 (79%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 1.111851
#
# Test set: Avg. loss: 0.6347, Accuracy: 7958/10000 (80%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 1.034450
#
# Test set: Avg. loss: 0.5942, Accuracy: 8184/10000 (82%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 1.219076
#
# Test set: Avg. loss: 0.5685, Accuracy: 8320/10000 (83%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.982456
#
# Test set: Avg. loss: 0.5445, Accuracy: 8352/10000 (84%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.871346
#
# Test set: Avg. loss: 0.5340, Accuracy: 8288/10000 (83%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 1.001057
#
# Test set: Avg. loss: 0.4989, Accuracy: 8484/10000 (85%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.959907
#
# Test set: Avg. loss: 0.4628, Accuracy: 8656/10000 (87%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 1.137003
#
# Test set: Avg. loss: 0.4499, Accuracy: 8673/10000 (87%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.732289
#
# Test set: Avg. loss: 0.4363, Accuracy: 8645/10000 (86%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 1.154896
#
# Test set: Avg. loss: 0.4203, Accuracy: 8679/10000 (87%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.898285
#
# Test set: Avg. loss: 0.4165, Accuracy: 8699/10000 (87%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 1.092379
#
# Test set: Avg. loss: 0.4305, Accuracy: 8648/10000 (86%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.958124
#
# Test set: Avg. loss: 0.4426, Accuracy: 8614/10000 (86%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.761564
#
# Test set: Avg. loss: 0.4508, Accuracy: 8588/10000 (86%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.883727
#
# Test set: Avg. loss: 0.4493, Accuracy: 8608/10000 (86%)
#
# Train Epoch: 51 [0/60000 (0%)]	Loss: 1.071461
#
# Test set: Avg. loss: 0.4424, Accuracy: 8686/10000 (87%)
#
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.831826
#
# Test set: Avg. loss: 0.4392, Accuracy: 8742/10000 (87%)
#
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.721595
#
# Test set: Avg. loss: 0.4325, Accuracy: 8795/10000 (88%)
#
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.721759
#
# Test set: Avg. loss: 0.4178, Accuracy: 8861/10000 (89%)
#
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.736978
#
# Test set: Avg. loss: 0.4070, Accuracy: 8868/10000 (89%)
#
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.990680
#
# Test set: Avg. loss: 0.3994, Accuracy: 8893/10000 (89%)
#
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.785204
#
# Test set: Avg. loss: 0.3967, Accuracy: 8863/10000 (89%)
#
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.843109
#
# Test set: Avg. loss: 0.4007, Accuracy: 8792/10000 (88%)
#
# Train Epoch: 59 [0/60000 (0%)]	Loss: 1.106817
#
# Test set: Avg. loss: 0.3892, Accuracy: 8812/10000 (88%)
#
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.795751
#
# Test set: Avg. loss: 0.3711, Accuracy: 8855/10000 (89%)
#
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.748929
#
# Test set: Avg. loss: 0.3511, Accuracy: 8919/10000 (89%)
#
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.801995
#
# Test set: Avg. loss: 0.3379, Accuracy: 8947/10000 (89%)
#
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.732838
#
# Test set: Avg. loss: 0.3322, Accuracy: 8943/10000 (89%)
#
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.633130
#
# Test set: Avg. loss: 0.3357, Accuracy: 8914/10000 (89%)
#
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.934150
#
# Test set: Avg. loss: 0.3445, Accuracy: 8937/10000 (89%)
#
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.992595
#
# Test set: Avg. loss: 0.3518, Accuracy: 8959/10000 (90%)
#
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.791196
#
# Test set: Avg. loss: 0.3523, Accuracy: 9017/10000 (90%)
#
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.908647
#
# Test set: Avg. loss: 0.3507, Accuracy: 9054/10000 (91%)
#
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.746999
#
# Test set: Avg. loss: 0.3394, Accuracy: 9097/10000 (91%)
#
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.740813
#
# Test set: Avg. loss: 0.3417, Accuracy: 9045/10000 (90%)
#
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.790238
#
# Test set: Avg. loss: 0.3511, Accuracy: 8992/10000 (90%)
#
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.674014
#
# Test set: Avg. loss: 0.3501, Accuracy: 8969/10000 (90%)
#
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.741537
#
# Test set: Avg. loss: 0.3447, Accuracy: 8974/10000 (90%)
#
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.825412
#
# Test set: Avg. loss: 0.3341, Accuracy: 9067/10000 (91%)
#
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.564556
#
# Test set: Avg. loss: 0.3279, Accuracy: 9069/10000 (91%)
#
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.661119
#
# Test set: Avg. loss: 0.3259, Accuracy: 9075/10000 (91%)
#
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.930490
#
# Test set: Avg. loss: 0.3391, Accuracy: 8994/10000 (90%)
#
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.645551
#
# Test set: Avg. loss: 0.3497, Accuracy: 8960/10000 (90%)
#
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.770345
# Test set: Avg. loss: 0.3602, Accuracy: 8900/10000 (89%)
#
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.680642
#
# Test set: Avg. loss: 0.3630, Accuracy: 8861/10000 (89%)
#
# Train Epoch: 81 [0/60000 (0%)]	Loss: 1.214631
#
# Test set: Avg. loss: 0.3501, Accuracy: 8900/10000 (89%)
#
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.612349
#
# Test set: Avg. loss: 0.3372, Accuracy: 8953/10000 (90%)
#
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.998993
#
# Test set: Avg. loss: 0.3240, Accuracy: 9039/10000 (90%)
#
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.865850
#
# Test set: Avg. loss: 0.3159, Accuracy: 9083/10000 (91%)
#
# Train Epoch: 85 [0/60000 (0%)]	Loss: 1.026730
#
# Test set: Avg. loss: 0.3126, Accuracy: 9124/10000 (91%)
#
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.988293
#
# Test set: Avg. loss: 0.3212, Accuracy: 9120/10000 (91%)
#
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.615276
#
# Test set: Avg. loss: 0.3312, Accuracy: 9094/10000 (91%)
#
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.945664
#
# Test set: Avg. loss: 0.3264, Accuracy: 9110/10000 (91%)
#
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.595504
#
# Test set: Avg. loss: 0.3217, Accuracy: 9122/10000 (91%)
#
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.727100
#
# Test set: Avg. loss: 0.3128, Accuracy: 9138/10000 (91%)
#
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.999801
#
# Test set: Avg. loss: 0.3086, Accuracy: 9137/10000 (91%)
#
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.957967
#
# Test set: Avg. loss: 0.3072, Accuracy: 9135/10000 (91%)
#
# Train Epoch: 93 [0/60000 (0%)]	Loss: 0.828161
#
# Test set: Avg. loss: 0.3042, Accuracy: 9129/10000 (91%)
#
# Train Epoch: 94 [0/60000 (0%)]	Loss: 0.903886
#
# Test set: Avg. loss: 0.2996, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 95 [0/60000 (0%)]	Loss: 0.891287
#
# Test set: Avg. loss: 0.2882, Accuracy: 9182/10000 (92%)
#
# Train Epoch: 96 [0/60000 (0%)]	Loss: 0.928151
#
# Test set: Avg. loss: 0.2839, Accuracy: 9196/10000 (92%)
#
# Train Epoch: 97 [0/60000 (0%)]	Loss: 0.606829
#
# Test set: Avg. loss: 0.2821, Accuracy: 9215/10000 (92%)
#
# Train Epoch: 98 [0/60000 (0%)]	Loss: 0.839665
#
# Test set: Avg. loss: 0.2761, Accuracy: 9240/10000 (92%)
#
# Train Epoch: 99 [0/60000 (0%)]	Loss: 0.765787
#
# Test set: Avg. loss: 0.2716, Accuracy: 9276/10000 (93%)
#
# Train Epoch: 100 [0/60000 (0%)]	Loss: 0.704314
#
# Test set: Avg. loss: 0.2682, Accuracy: 9296/10000 (93%)
#
# Train Epoch: 101 [0/60000 (0%)]	Loss: 0.625988
#
# Test set: Avg. loss: 0.2674, Accuracy: 9299/10000 (93%)
#
# Train Epoch: 102 [0/60000 (0%)]	Loss: 1.023597
#
# Test set: Avg. loss: 0.2663, Accuracy: 9317/10000 (93%)
#
# Train Epoch: 103 [0/60000 (0%)]	Loss: 0.612476
#
# Test set: Avg. loss: 0.2628, Accuracy: 9323/10000 (93%)
#
# Train Epoch: 104 [0/60000 (0%)]	Loss: 0.892815
#
# Test set: Avg. loss: 0.2611, Accuracy: 9305/10000 (93%)
#
# Train Epoch: 105 [0/60000 (0%)]	Loss: 0.580681
#
# Test set: Avg. loss: 0.2620, Accuracy: 9278/10000 (93%)
#
# Train Epoch: 106 [0/60000 (0%)]	Loss: 0.554516
#
# Test set: Avg. loss: 0.2627, Accuracy: 9269/10000 (93%)
#
# Train Epoch: 107 [0/60000 (0%)]	Loss: 0.734548
#
# Test set: Avg. loss: 0.2632, Accuracy: 9256/10000 (93%)
#
# Train Epoch: 108 [0/60000 (0%)]	Loss: 0.459077
#
# Test set: Avg. loss: 0.2600, Accuracy: 9261/10000 (93%)
#
# Train Epoch: 109 [0/60000 (0%)]	Loss: 0.845534
#
# Test set: Avg. loss: 0.2508, Accuracy: 9281/10000 (93%)
#
# Train Epoch: 110 [0/60000 (0%)]	Loss: 0.537729
#
# Test set: Avg. loss: 0.2445, Accuracy: 9300/10000 (93%)
#
# Train Epoch: 111 [0/60000 (0%)]	Loss: 0.539496
#
# Test set: Avg. loss: 0.2372, Accuracy: 9303/10000 (93%)
#
# Train Epoch: 112 [0/60000 (0%)]	Loss: 0.447211
#
# Test set: Avg. loss: 0.2324, Accuracy: 9305/10000 (93%)
#
# Train Epoch: 113 [0/60000 (0%)]	Loss: 0.380854
#
# Test set: Avg. loss: 0.2331, Accuracy: 9282/10000 (93%)
#
# Train Epoch: 114 [0/60000 (0%)]	Loss: 0.476074
#
# Test set: Avg. loss: 0.2448, Accuracy: 9221/10000 (92%)
#
# Train Epoch: 115 [0/60000 (0%)]	Loss: 0.728048
#
# Test set: Avg. loss: 0.2552, Accuracy: 9172/10000 (92%)
#
# Train Epoch: 116 [0/60000 (0%)]	Loss: 1.035273
#
# Test set: Avg. loss: 0.2638, Accuracy: 9140/10000 (91%)
#
# Train Epoch: 117 [0/60000 (0%)]	Loss: 0.964964
#
# Test set: Avg. loss: 0.2740, Accuracy: 9098/10000 (91%)
#
# Train Epoch: 118 [0/60000 (0%)]	Loss: 1.346807
#
# Test set: Avg. loss: 0.2673, Accuracy: 9156/10000 (92%)
#
# Train Epoch: 119 [0/60000 (0%)]	Loss: 1.010333
#
# Test set: Avg. loss: 0.2627, Accuracy: 9222/10000 (92%)
#
# Train Epoch: 120 [0/60000 (0%)]	Loss: 0.456569
#
# Test set: Avg. loss: 0.2675, Accuracy: 9266/10000 (93%)
#
# Train Epoch: 121 [0/60000 (0%)]	Loss: 0.659343
#
# Test set: Avg. loss: 0.2724, Accuracy: 9304/10000 (93%)
#
# Train Epoch: 122 [0/60000 (0%)]	Loss: 0.601248
#
# Test set: Avg. loss: 0.2835, Accuracy: 9290/10000 (93%)
#
# Train Epoch: 123 [0/60000 (0%)]	Loss: 0.572030
#
# Test set: Avg. loss: 0.2900, Accuracy: 9291/10000 (93%)
#
# Train Epoch: 124 [0/60000 (0%)]	Loss: 0.668747
#
# Test set: Avg. loss: 0.2975, Accuracy: 9233/10000 (92%)
#
# Train Epoch: 125 [0/60000 (0%)]	Loss: 0.607330
#
# Test set: Avg. loss: 0.3028, Accuracy: 9165/10000 (92%)
#
# Train Epoch: 126 [0/60000 (0%)]	Loss: 0.658522
#
# Test set: Avg. loss: 0.2937, Accuracy: 9186/10000 (92%)
#
# Train Epoch: 127 [0/60000 (0%)]	Loss: 0.461408
#
# Test set: Avg. loss: 0.2821, Accuracy: 9181/10000 (92%)
#
# Train Epoch: 128 [0/60000 (0%)]	Loss: 0.660667
#
# Test set: Avg. loss: 0.2707, Accuracy: 9179/10000 (92%)
#
# Train Epoch: 129 [0/60000 (0%)]	Loss: 0.414872
#
# Test set: Avg. loss: 0.2629, Accuracy: 9185/10000 (92%)
#
# Train Epoch: 130 [0/60000 (0%)]	Loss: 0.866457
#
# Test set: Avg. loss: 0.2538, Accuracy: 9215/10000 (92%)
#
# Train Epoch: 131 [0/60000 (0%)]	Loss: 0.851333
#
# Test set: Avg. loss: 0.2412, Accuracy: 9279/10000 (93%)
#
# Train Epoch: 132 [0/60000 (0%)]	Loss: 0.586329
#
# Test set: Avg. loss: 0.2350, Accuracy: 9289/10000 (93%)
#
# Train Epoch: 133 [0/60000 (0%)]	Loss: 0.658082
#
# Test set: Avg. loss: 0.2264, Accuracy: 9322/10000 (93%)
#
# Train Epoch: 134 [0/60000 (0%)]	Loss: 0.457258
#
# Test set: Avg. loss: 0.2187, Accuracy: 9339/10000 (93%)
#
# Train Epoch: 135 [0/60000 (0%)]	Loss: 0.475382
#
# Test set: Avg. loss: 0.2171, Accuracy: 9332/10000 (93%)
#
# Train Epoch: 136 [0/60000 (0%)]	Loss: 0.347438
#
# Test set: Avg. loss: 0.2197, Accuracy: 9313/10000 (93%)
#
# Train Epoch: 137 [0/60000 (0%)]	Loss: 0.856446
#
# Test set: Avg. loss: 0.2207, Accuracy: 9295/10000 (93%)
#
# Train Epoch: 138 [0/60000 (0%)]	Loss: 0.575420
#
# Test set: Avg. loss: 0.2284, Accuracy: 9224/10000 (92%)
#
# Train Epoch: 139 [0/60000 (0%)]	Loss: 0.433695
#
# Test set: Avg. loss: 0.2291, Accuracy: 9205/10000 (92%)
#
# Train Epoch: 140 [0/60000 (0%)]	Loss: 0.636615
#
# Test set: Avg. loss: 0.2314, Accuracy: 9191/10000 (92%)
#
# Train Epoch: 141 [0/60000 (0%)]	Loss: 0.908186
#
# Test set: Avg. loss: 0.2222, Accuracy: 9246/10000 (92%)
#
# Train Epoch: 142 [0/60000 (0%)]	Loss: 0.497150
#
# Test set: Avg. loss: 0.2145, Accuracy: 9303/10000 (93%)
#
# Train Epoch: 143 [0/60000 (0%)]	Loss: 0.478387
#
# Test set: Avg. loss: 0.2068, Accuracy: 9353/10000 (94%)
#
# Train Epoch: 144 [0/60000 (0%)]	Loss: 0.678365
#
# Test set: Avg. loss: 0.2039, Accuracy: 9386/10000 (94%)
#
# Train Epoch: 145 [0/60000 (0%)]	Loss: 0.795672
#
# Test set: Avg. loss: 0.2083, Accuracy: 9361/10000 (94%)
#
# Train Epoch: 146 [0/60000 (0%)]	Loss: 0.596114
#
# Test set: Avg. loss: 0.2171, Accuracy: 9321/10000 (93%)
#
# Train Epoch: 147 [0/60000 (0%)]	Loss: 0.479174
#
# Test set: Avg. loss: 0.2221, Accuracy: 9298/10000 (93%)
#
# Train Epoch: 148 [0/60000 (0%)]	Loss: 0.641978
#
# Test set: Avg. loss: 0.2203, Accuracy: 9333/10000 (93%)
#
# Train Epoch: 149 [0/60000 (0%)]	Loss: 0.356413
#
# Test set: Avg. loss: 0.2143, Accuracy: 9367/10000 (94%)
#
# Train Epoch: 150 [0/60000 (0%)]	Loss: 0.488421
#
# Test set: Avg. loss: 0.2117, Accuracy: 9377/10000 (94%)
#
# Train Epoch: 151 [0/60000 (0%)]	Loss: 0.478872
#
# Test set: Avg. loss: 0.2094, Accuracy: 9387/10000 (94%)
#
# Train Epoch: 152 [0/60000 (0%)]	Loss: 0.621665
#
# Test set: Avg. loss: 0.2064, Accuracy: 9396/10000 (94%)
#
# Train Epoch: 153 [0/60000 (0%)]	Loss: 0.536553
#
# Test set: Avg. loss: 0.2065, Accuracy: 9383/10000 (94%)
#
# Train Epoch: 154 [0/60000 (0%)]	Loss: 0.961834
#
# Test set: Avg. loss: 0.2106, Accuracy: 9379/10000 (94%)
#
# Train Epoch: 155 [0/60000 (0%)]	Loss: 0.455392
#
# Test set: Avg. loss: 0.2146, Accuracy: 9353/10000 (94%)
#
# Train Epoch: 156 [0/60000 (0%)]	Loss: 0.592248
#
# Test set: Avg. loss: 0.2145, Accuracy: 9374/10000 (94%)
#
# Train Epoch: 157 [0/60000 (0%)]	Loss: 0.655525
#
# Test set: Avg. loss: 0.2201, Accuracy: 9357/10000 (94%)
#
# Train Epoch: 158 [0/60000 (0%)]	Loss: 0.484066
# Test set: Avg. loss: 0.2273, Accuracy: 9322/10000 (93%)
#
# Train Epoch: 159 [0/60000 (0%)]	Loss: 0.869928
#
# Test set: Avg. loss: 0.2292, Accuracy: 9334/10000 (93%)
#
# Train Epoch: 160 [0/60000 (0%)]	Loss: 0.426671
#
# Test set: Avg. loss: 0.2244, Accuracy: 9352/10000 (94%)
#
# Train Epoch: 161 [0/60000 (0%)]	Loss: 0.574760
#
# Test set: Avg. loss: 0.2220, Accuracy: 9344/10000 (93%)
#
# Train Epoch: 162 [0/60000 (0%)]	Loss: 0.748141
#
# Test set: Avg. loss: 0.2247, Accuracy: 9347/10000 (93%)
#
# Train Epoch: 163 [0/60000 (0%)]	Loss: 0.448712
#
# Test set: Avg. loss: 0.2344, Accuracy: 9331/10000 (93%)
#
# Train Epoch: 164 [0/60000 (0%)]	Loss: 0.790906
#
# Test set: Avg. loss: 0.2380, Accuracy: 9344/10000 (93%)
#
# Train Epoch: 165 [0/60000 (0%)]	Loss: 0.900852
#
# Test set: Avg. loss: 0.2394, Accuracy: 9343/10000 (93%)
#
# Train Epoch: 166 [0/60000 (0%)]	Loss: 0.760807
#
# Test set: Avg. loss: 0.2442, Accuracy: 9330/10000 (93%)
#
# Train Epoch: 167 [0/60000 (0%)]	Loss: 0.544080
#
# Test set: Avg. loss: 0.2504, Accuracy: 9294/10000 (93%)
#
# Train Epoch: 168 [0/60000 (0%)]	Loss: 0.771542
#
# Test set: Avg. loss: 0.2488, Accuracy: 9298/10000 (93%)
#
# Train Epoch: 169 [0/60000 (0%)]	Loss: 0.639495
#
# Test set: Avg. loss: 0.2418, Accuracy: 9312/10000 (93%)
#
# Train Epoch: 170 [0/60000 (0%)]	Loss: 0.591585
#
# Test set: Avg. loss: 0.2329, Accuracy: 9349/10000 (93%)
#
# Train Epoch: 171 [0/60000 (0%)]	Loss: 0.457312
#
# Test set: Avg. loss: 0.2274, Accuracy: 9352/10000 (94%)
#
# Train Epoch: 172 [0/60000 (0%)]	Loss: 0.677330
#
# Test set: Avg. loss: 0.2264, Accuracy: 9338/10000 (93%)
#
# Train Epoch: 173 [0/60000 (0%)]	Loss: 0.526962
#
# Test set: Avg. loss: 0.2256, Accuracy: 9330/10000 (93%)
#
# Train Epoch: 174 [0/60000 (0%)]	Loss: 0.624798
#
# Test set: Avg. loss: 0.2214, Accuracy: 9351/10000 (94%)
#
# Train Epoch: 175 [0/60000 (0%)]	Loss: 0.419671
#
# Test set: Avg. loss: 0.2181, Accuracy: 9331/10000 (93%)
#
# Train Epoch: 176 [0/60000 (0%)]	Loss: 0.491502
#
# Test set: Avg. loss: 0.2171, Accuracy: 9313/10000 (93%)
#
# Train Epoch: 177 [0/60000 (0%)]	Loss: 0.497500
#
# Test set: Avg. loss: 0.2140, Accuracy: 9328/10000 (93%)
#
# Train Epoch: 178 [0/60000 (0%)]	Loss: 0.412975
#
# Test set: Avg. loss: 0.2128, Accuracy: 9321/10000 (93%)
#
# Train Epoch: 179 [0/60000 (0%)]	Loss: 0.635776
#
# Test set: Avg. loss: 0.2129, Accuracy: 9318/10000 (93%)
#
# Train Epoch: 180 [0/60000 (0%)]	Loss: 0.438102
#
# Test set: Avg. loss: 0.2094, Accuracy: 9324/10000 (93%)
#
# Train Epoch: 181 [0/60000 (0%)]	Loss: 0.528969
#
# Test set: Avg. loss: 0.2146, Accuracy: 9290/10000 (93%)
#
# Train Epoch: 182 [0/60000 (0%)]	Loss: 0.617284
#
# Test set: Avg. loss: 0.2129, Accuracy: 9313/10000 (93%)
#
# Train Epoch: 183 [0/60000 (0%)]	Loss: 0.635204
#
# Test set: Avg. loss: 0.2038, Accuracy: 9360/10000 (94%)
#
# Train Epoch: 184 [0/60000 (0%)]	Loss: 0.787368
#
# Test set: Avg. loss: 0.1916, Accuracy: 9395/10000 (94%)
#
# Train Epoch: 185 [0/60000 (0%)]	Loss: 0.552211
#
# Test set: Avg. loss: 0.1850, Accuracy: 9428/10000 (94%)
#
# Train Epoch: 186 [0/60000 (0%)]	Loss: 1.064710
#
# Test set: Avg. loss: 0.1860, Accuracy: 9431/10000 (94%)
#
# Train Epoch: 187 [0/60000 (0%)]	Loss: 0.732304
#
# Test set: Avg. loss: 0.1923, Accuracy: 9415/10000 (94%)
#
# Train Epoch: 188 [0/60000 (0%)]	Loss: 0.623368
#
# Test set: Avg. loss: 0.2002, Accuracy: 9381/10000 (94%)
#
# Train Epoch: 189 [0/60000 (0%)]	Loss: 0.530062
#
# Test set: Avg. loss: 0.2074, Accuracy: 9366/10000 (94%)
#
# Train Epoch: 190 [0/60000 (0%)]	Loss: 0.417747
#
# Test set: Avg. loss: 0.2145, Accuracy: 9338/10000 (93%)
#
# Train Epoch: 191 [0/60000 (0%)]	Loss: 0.503134
#
# Test set: Avg. loss: 0.2179, Accuracy: 9334/10000 (93%)
#
# Train Epoch: 192 [0/60000 (0%)]	Loss: 0.475255
#
# Test set: Avg. loss: 0.2186, Accuracy: 9329/10000 (93%)
#
# Train Epoch: 193 [0/60000 (0%)]	Loss: 0.534891
#
# Test set: Avg. loss: 0.2155, Accuracy: 9342/10000 (93%)
#
# Train Epoch: 194 [0/60000 (0%)]	Loss: 0.614498
#
# Test set: Avg. loss: 0.2125, Accuracy: 9335/10000 (93%)
#
# Train Epoch: 195 [0/60000 (0%)]	Loss: 0.656417
#
# Test set: Avg. loss: 0.2124, Accuracy: 9357/10000 (94%)
#
# Train Epoch: 196 [0/60000 (0%)]	Loss: 0.503482
#
# Test set: Avg. loss: 0.2147, Accuracy: 9347/10000 (93%)
#
# Train Epoch: 197 [0/60000 (0%)]	Loss: 0.400100
#
# Test set: Avg. loss: 0.2180, Accuracy: 9337/10000 (93%)
#
# Train Epoch: 198 [0/60000 (0%)]	Loss: 0.288835
#
# Test set: Avg. loss: 0.2196, Accuracy: 9343/10000 (93%)
#
# Train Epoch: 199 [0/60000 (0%)]	Loss: 0.470860
#
# Test set: Avg. loss: 0.2221, Accuracy: 9329/10000 (93%)
#
# Train Epoch: 200 [0/60000 (0%)]	Loss: 0.580550
#
# Test set: Avg. loss: 0.2206, Accuracy: 9332/10000 (93%)
#
# Train Epoch: 201 [0/60000 (0%)]	Loss: 0.334814
#
# Test set: Avg. loss: 0.2134, Accuracy: 9354/10000 (94%)
#
# Train Epoch: 202 [0/60000 (0%)]	Loss: 0.627681
#
# Test set: Avg. loss: 0.2112, Accuracy: 9360/10000 (94%)
#
# Train Epoch: 203 [0/60000 (0%)]	Loss: 0.529827
#
# Test set: Avg. loss: 0.2056, Accuracy: 9372/10000 (94%)
#
# Train Epoch: 204 [0/60000 (0%)]	Loss: 0.691550
#
# Test set: Avg. loss: 0.2019, Accuracy: 9378/10000 (94%)
#
# Train Epoch: 205 [0/60000 (0%)]	Loss: 0.542284
#
# Test set: Avg. loss: 0.2014, Accuracy: 9401/10000 (94%)
#
# Train Epoch: 206 [0/60000 (0%)]	Loss: 0.552715
#
# Test set: Avg. loss: 0.2019, Accuracy: 9383/10000 (94%)
#
# Train Epoch: 207 [0/60000 (0%)]	Loss: 0.933826
#
# Test set: Avg. loss: 0.1988, Accuracy: 9401/10000 (94%)
#
# Train Epoch: 208 [0/60000 (0%)]	Loss: 0.563991
#
# Test set: Avg. loss: 0.2033, Accuracy: 9397/10000 (94%)
#
# Train Epoch: 209 [0/60000 (0%)]	Loss: 0.703531
#
# Test set: Avg. loss: 0.2035, Accuracy: 9405/10000 (94%)
#
# Train Epoch: 210 [0/60000 (0%)]	Loss: 0.576454
#
# Test set: Avg. loss: 0.2023, Accuracy: 9412/10000 (94%)
#
# Train Epoch: 211 [0/60000 (0%)]	Loss: 0.629776
#
# Test set: Avg. loss: 0.1988, Accuracy: 9438/10000 (94%)
#
# Train Epoch: 212 [0/60000 (0%)]	Loss: 0.464077
#
# Test set: Avg. loss: 0.1962, Accuracy: 9449/10000 (94%)
#
# Train Epoch: 213 [0/60000 (0%)]	Loss: 0.430338
#
# Test set: Avg. loss: 0.1959, Accuracy: 9459/10000 (95%)
#
# Train Epoch: 214 [0/60000 (0%)]	Loss: 0.618347
#
# Test set: Avg. loss: 0.1942, Accuracy: 9460/10000 (95%)
#
# Train Epoch: 215 [0/60000 (0%)]	Loss: 0.439134
#
# Test set: Avg. loss: 0.1951, Accuracy: 9473/10000 (95%)
#
# Train Epoch: 216 [0/60000 (0%)]	Loss: 0.534022
#
# Test set: Avg. loss: 0.1989, Accuracy: 9465/10000 (95%)
#
# Train Epoch: 217 [0/60000 (0%)]	Loss: 0.256757
#
# Test set: Avg. loss: 0.2067, Accuracy: 9416/10000 (94%)
#
# Train Epoch: 218 [0/60000 (0%)]	Loss: 0.428437
#
# Test set: Avg. loss: 0.2177, Accuracy: 9375/10000 (94%)
#
# Train Epoch: 219 [0/60000 (0%)]	Loss: 0.654817
#
# Test set: Avg. loss: 0.2182, Accuracy: 9364/10000 (94%)
#
# Train Epoch: 220 [0/60000 (0%)]	Loss: 0.385315
#
# Test set: Avg. loss: 0.2149, Accuracy: 9380/10000 (94%)
#
# Train Epoch: 221 [0/60000 (0%)]	Loss: 0.878110
#
# Test set: Avg. loss: 0.2110, Accuracy: 9408/10000 (94%)
#
# Train Epoch: 222 [0/60000 (0%)]	Loss: 0.665655
#
# Test set: Avg. loss: 0.2081, Accuracy: 9407/10000 (94%)
#
# Train Epoch: 223 [0/60000 (0%)]	Loss: 0.479979
#
# Test set: Avg. loss: 0.2068, Accuracy: 9409/10000 (94%)
#
# Train Epoch: 224 [0/60000 (0%)]	Loss: 0.690690
#
# Test set: Avg. loss: 0.2035, Accuracy: 9398/10000 (94%)
#
# Train Epoch: 225 [0/60000 (0%)]	Loss: 0.603802
#
# Test set: Avg. loss: 0.2038, Accuracy: 9406/10000 (94%)
#
# Train Epoch: 226 [0/60000 (0%)]	Loss: 0.577465
#
# Test set: Avg. loss: 0.2043, Accuracy: 9420/10000 (94%)
#
# Train Epoch: 227 [0/60000 (0%)]	Loss: 0.643544
#
# Test set: Avg. loss: 0.2050, Accuracy: 9394/10000 (94%)
#
# Train Epoch: 228 [0/60000 (0%)]	Loss: 0.574548
#
# Test set: Avg. loss: 0.2049, Accuracy: 9387/10000 (94%)
#
# Train Epoch: 229 [0/60000 (0%)]	Loss: 0.415312
#
# Test set: Avg. loss: 0.2023, Accuracy: 9400/10000 (94%)
#
# Train Epoch: 230 [0/60000 (0%)]	Loss: 0.507018
#
# Test set: Avg. loss: 0.1985, Accuracy: 9414/10000 (94%)
#
# Train Epoch: 231 [0/60000 (0%)]	Loss: 0.632323
#
# Test set: Avg. loss: 0.1923, Accuracy: 9441/10000 (94%)
#
# Train Epoch: 232 [0/60000 (0%)]	Loss: 0.442018
#
# Test set: Avg. loss: 0.1826, Accuracy: 9455/10000 (95%)
#
# Train Epoch: 233 [0/60000 (0%)]	Loss: 0.581594
#
# Test set: Avg. loss: 0.1764, Accuracy: 9483/10000 (95%)
#
# Train Epoch: 234 [0/60000 (0%)]	Loss: 0.437090
#
# Test set: Avg. loss: 0.1748, Accuracy: 9500/10000 (95%)
#
# Train Epoch: 235 [0/60000 (0%)]	Loss: 0.521338
#
# Test set: Avg. loss: 0.1775, Accuracy: 9481/10000 (95%)
#
# Train Epoch: 236 [0/60000 (0%)]	Loss: 0.489148
#
# Test set: Avg. loss: 0.1821, Accuracy: 9475/10000 (95%)
#
# Train Epoch: 237 [0/60000 (0%)]	Loss: 0.375061
# Test set: Avg. loss: 0.1890, Accuracy: 9466/10000 (95%)
#
# Train Epoch: 238 [0/60000 (0%)]	Loss: 0.762971
#
# Test set: Avg. loss: 0.1872, Accuracy: 9473/10000 (95%)
#
# Train Epoch: 239 [0/60000 (0%)]	Loss: 0.387507
#
# Test set: Avg. loss: 0.1926, Accuracy: 9441/10000 (94%)
#
# Train Epoch: 240 [0/60000 (0%)]	Loss: 0.466639
#
# Test set: Avg. loss: 0.2077, Accuracy: 9421/10000 (94%)
#
# Train Epoch: 241 [0/60000 (0%)]	Loss: 0.594257
#
# Test set: Avg. loss: 0.2061, Accuracy: 9426/10000 (94%)
#
# Train Epoch: 242 [0/60000 (0%)]	Loss: 0.346519
#
# Test set: Avg. loss: 0.1947, Accuracy: 9443/10000 (94%)
#
# Train Epoch: 243 [0/60000 (0%)]	Loss: 0.869658
#
# Test set: Avg. loss: 0.1837, Accuracy: 9470/10000 (95%)
#
# Train Epoch: 244 [0/60000 (0%)]	Loss: 0.727431
#
# Test set: Avg. loss: 0.1751, Accuracy: 9503/10000 (95%)
#
# Train Epoch: 245 [0/60000 (0%)]	Loss: 0.445047
#
# Test set: Avg. loss: 0.1743, Accuracy: 9493/10000 (95%)
#
# Train Epoch: 246 [0/60000 (0%)]	Loss: 0.423295
#
# Test set: Avg. loss: 0.1754, Accuracy: 9472/10000 (95%)
#
# Train Epoch: 247 [0/60000 (0%)]	Loss: 0.341203
#
# Test set: Avg. loss: 0.1739, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 248 [0/60000 (0%)]	Loss: 0.641080
#
# Test set: Avg. loss: 0.1698, Accuracy: 9499/10000 (95%)
#
# Train Epoch: 249 [0/60000 (0%)]	Loss: 0.243589
#
# Test set: Avg. loss: 0.1714, Accuracy: 9499/10000 (95%)
#
# Train Epoch: 250 [0/60000 (0%)]	Loss: 0.682748
#
# Test set: Avg. loss: 0.1656, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 251 [0/60000 (0%)]	Loss: 0.509349
#
# Test set: Avg. loss: 0.1613, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 252 [0/60000 (0%)]	Loss: 0.434132
#
# Test set: Avg. loss: 0.1604, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 253 [0/60000 (0%)]	Loss: 0.825635
#
# Test set: Avg. loss: 0.1615, Accuracy: 9555/10000 (96%)
#
# Train Epoch: 254 [0/60000 (0%)]	Loss: 0.457917
#
# Test set: Avg. loss: 0.1640, Accuracy: 9549/10000 (95%)
#
# Train Epoch: 255 [0/60000 (0%)]	Loss: 0.401594
#
# Test set: Avg. loss: 0.1667, Accuracy: 9540/10000 (95%)
#
# Train Epoch: 256 [0/60000 (0%)]	Loss: 0.445693
#
# Test set: Avg. loss: 0.1681, Accuracy: 9546/10000 (95%)
#
# Train Epoch: 257 [0/60000 (0%)]	Loss: 0.723583
#
# Test set: Avg. loss: 0.1678, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 258 [0/60000 (0%)]	Loss: 0.516230
#
# Test set: Avg. loss: 0.1684, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 259 [0/60000 (0%)]	Loss: 0.761689
#
# Test set: Avg. loss: 0.1693, Accuracy: 9526/10000 (95%)
#
# Train Epoch: 260 [0/60000 (0%)]	Loss: 0.401148
#
# Test set: Avg. loss: 0.1692, Accuracy: 9527/10000 (95%)
#
# Train Epoch: 261 [0/60000 (0%)]	Loss: 0.648744
#
# Test set: Avg. loss: 0.1693, Accuracy: 9511/10000 (95%)
#
# Train Epoch: 262 [0/60000 (0%)]	Loss: 0.629235
#
# Test set: Avg. loss: 0.1707, Accuracy: 9507/10000 (95%)
#
# Train Epoch: 263 [0/60000 (0%)]	Loss: 0.497526
#
# Test set: Avg. loss: 0.1728, Accuracy: 9498/10000 (95%)
#
# Train Epoch: 264 [0/60000 (0%)]	Loss: 0.421030
#
# Test set: Avg. loss: 0.1775, Accuracy: 9475/10000 (95%)
#
# Train Epoch: 265 [0/60000 (0%)]	Loss: 0.492746
#
# Test set: Avg. loss: 0.1800, Accuracy: 9481/10000 (95%)
#
# Train Epoch: 266 [0/60000 (0%)]	Loss: 0.437020
#
# Test set: Avg. loss: 0.1815, Accuracy: 9457/10000 (95%)
#
# Train Epoch: 267 [0/60000 (0%)]	Loss: 0.344158
#
# Test set: Avg. loss: 0.1791, Accuracy: 9461/10000 (95%)
#
# Train Epoch: 268 [0/60000 (0%)]	Loss: 0.644624
#
# Test set: Avg. loss: 0.1751, Accuracy: 9470/10000 (95%)
#
# Train Epoch: 269 [0/60000 (0%)]	Loss: 0.870170
#
# Test set: Avg. loss: 0.1654, Accuracy: 9506/10000 (95%)
#
# Train Epoch: 270 [0/60000 (0%)]	Loss: 0.464422
#
# Test set: Avg. loss: 0.1594, Accuracy: 9533/10000 (95%)
#
# Train Epoch: 271 [0/60000 (0%)]	Loss: 0.329000
#
# Test set: Avg. loss: 0.1577, Accuracy: 9544/10000 (95%)
#
# Train Epoch: 272 [0/60000 (0%)]	Loss: 0.323616
#
# Test set: Avg. loss: 0.1587, Accuracy: 9538/10000 (95%)
#
# Train Epoch: 273 [0/60000 (0%)]	Loss: 0.646030
#
# Test set: Avg. loss: 0.1621, Accuracy: 9527/10000 (95%)
#
# Train Epoch: 274 [0/60000 (0%)]	Loss: 0.613488
#
# Test set: Avg. loss: 0.1664, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 275 [0/60000 (0%)]	Loss: 0.523562
#
# Test set: Avg. loss: 0.1714, Accuracy: 9505/10000 (95%)
#
# Train Epoch: 276 [0/60000 (0%)]	Loss: 0.545283
#
# Test set: Avg. loss: 0.1778, Accuracy: 9488/10000 (95%)
#
# Train Epoch: 277 [0/60000 (0%)]	Loss: 0.510197
#
# Test set: Avg. loss: 0.1830, Accuracy: 9469/10000 (95%)
#
# Train Epoch: 278 [0/60000 (0%)]	Loss: 0.477836
#
# Test set: Avg. loss: 0.1808, Accuracy: 9480/10000 (95%)
#
# Train Epoch: 279 [0/60000 (0%)]	Loss: 0.515292
#
# Test set: Avg. loss: 0.1751, Accuracy: 9493/10000 (95%)
#
# Train Epoch: 280 [0/60000 (0%)]	Loss: 0.475318
#
# Test set: Avg. loss: 0.1716, Accuracy: 9495/10000 (95%)
#
# Train Epoch: 281 [0/60000 (0%)]	Loss: 0.478699
#
# Test set: Avg. loss: 0.1678, Accuracy: 9500/10000 (95%)
#
# Train Epoch: 282 [0/60000 (0%)]	Loss: 0.565191
#
# Test set: Avg. loss: 0.1632, Accuracy: 9518/10000 (95%)
#
# Train Epoch: 283 [0/60000 (0%)]	Loss: 0.357875
#
# Test set: Avg. loss: 0.1623, Accuracy: 9514/10000 (95%)
#
# Train Epoch: 284 [0/60000 (0%)]	Loss: 0.591820
#
# Test set: Avg. loss: 0.1621, Accuracy: 9522/10000 (95%)
#
# Train Epoch: 285 [0/60000 (0%)]	Loss: 0.379307
#
# Test set: Avg. loss: 0.1626, Accuracy: 9517/10000 (95%)
#
# Train Epoch: 286 [0/60000 (0%)]	Loss: 0.703043
#
# Test set: Avg. loss: 0.1622, Accuracy: 9525/10000 (95%)
#
# Train Epoch: 287 [0/60000 (0%)]	Loss: 0.494357
#
# Test set: Avg. loss: 0.1618, Accuracy: 9543/10000 (95%)
#
# Train Epoch: 288 [0/60000 (0%)]	Loss: 0.492816
#
# Test set: Avg. loss: 0.1622, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 289 [0/60000 (0%)]	Loss: 0.534170
#
# Test set: Avg. loss: 0.1630, Accuracy: 9558/10000 (96%)
#
# Train Epoch: 290 [0/60000 (0%)]	Loss: 0.792455
#
# Test set: Avg. loss: 0.1652, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 291 [0/60000 (0%)]	Loss: 0.722051
#
# Test set: Avg. loss: 0.1679, Accuracy: 9555/10000 (96%)
#
# Train Epoch: 292 [0/60000 (0%)]	Loss: 0.570270
#
# Test set: Avg. loss: 0.1698, Accuracy: 9550/10000 (96%)
#
# Train Epoch: 293 [0/60000 (0%)]	Loss: 0.451927
#
# Test set: Avg. loss: 0.1705, Accuracy: 9544/10000 (95%)
#
# Train Epoch: 294 [0/60000 (0%)]	Loss: 0.355609
#
# Test set: Avg. loss: 0.1692, Accuracy: 9548/10000 (95%)
#
# Train Epoch: 295 [0/60000 (0%)]	Loss: 0.326272
#
# Test set: Avg. loss: 0.1684, Accuracy: 9550/10000 (96%)
#
# Train Epoch: 296 [0/60000 (0%)]	Loss: 0.332380
#
# Test set: Avg. loss: 0.1680, Accuracy: 9548/10000 (95%)
#
# Train Epoch: 297 [0/60000 (0%)]	Loss: 0.626020
#
# Test set: Avg. loss: 0.1659, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 298 [0/60000 (0%)]	Loss: 0.483729
#
# Test set: Avg. loss: 0.1649, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 299 [0/60000 (0%)]	Loss: 0.475021
#
# Test set: Avg. loss: 0.1682, Accuracy: 9525/10000 (95%)
#
# Train Epoch: 300 [0/60000 (0%)]	Loss: 0.571899
#
# Test set: Avg. loss: 0.1782, Accuracy: 9501/10000 (95%)

# %%
images, labels = next(iter(val_loader))

# %%
next(model.parameters()).is_cuda
# Out:
# True

# %%
# img = images[0].view(1, 784)
print(images.is_cuda)
images = images.to(device)
with torch.no_grad():
    logps = model(images)

ps = torch.exp(logps)
probab = list(ps.numpy()[0])
print("Predicted Digit =", probab.index(max(probab)))
view_classify(img.view(1, 28, 28), ps)
# Out:
# False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-0509a70fba48> in <module>
#       2 print(images.is_cuda)
#       3 with torch.no_grad():
# ----> 4     logps = model(images)
#       5
#       6 ps = torch.exp(logps)
#
# ~/.conda/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-5-16d158114b6c> in forward(self, x)
#       9
#      10     def forward(self, x):
# ---> 11         x = F.relu(F.max_pool2d(self.conv1(x), 2))
#      12         x = F.relu(F.max_pool2d(self.dropput(self.conv2(x)), 2))
#      13         x = x.view(-1, 320)
#
# ~/.conda/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.conda/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~/.conda/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same
